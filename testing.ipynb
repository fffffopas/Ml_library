# %%
from linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from linear_model import LinearRegression
#
# ImportError: cannot import name 'LinearRegression' from 'linear_model' (c:\Users\danil\MachineLearning\ML_LIBRARY\linear_model\__init__.py)
